# %%
import os
from pandas import read_csv, read_excel, DataFrame
import sae
import gurobipy as gp
from gurobipy import GRB
import numpy as np

import sys
sys.path.append('../../')
import saedfsc

# %%
saedfsc.suppliers
# Out:
#         Name   Location    Rating  SetUpCost
# 0  Supplier1  Location1  1.178742       4303
# 1  Supplier2  Location2  2.930649       2174
# 2  Supplier3  Location1  4.821298       2699
# 3  Supplier4  Location4  2.837146       2724
# 4  Supplier5  Location2  3.659921       4715
# 5  Supplier6  Location2  1.560158       2056
# 6  Supplier7  Location3  1.165378       3938

# %%
partOptions = saedfsc.getPartOptionsWithSuppliers()
partOptions['wings']
# Out:
#       Unnamed: 0_x                      Material  Code     q             E  \
# 909              4      Glass-filled nylon (35%)   GFN  1600   14900000000
# 396              1                     Nylon 6/6   N66  1150    2400000000
# 885              4      Glass-filled nylon (35%)   GFN  1600   14900000000
# 1255             5           S-glass epoxy (45%)   SGE  1800   39500000000
# 1354             6      Glass-filled epoxy (35%)   GFE  1900   25000000000
# 2591            11           Cast Iron, grade 20  CI20  7150  100000000000
# 1642             7  Glass-filled polyester (35%)   GFP  2000   15700000000
# 28               0           Polyethylene (HDPE)  HDPE   900     900000000
# 2532            11           Cast Iron, grade 20  CI20  7150  100000000000
# 1858             8              Aluminum 2045-T4   AT4  2700   73000000000
# 680              3            Kevlar epoxy (53%)    KE  1350   63600000000
# 748              3            Kevlar epoxy (53%)    KE  1350   63600000000
# 335              1                     Nylon 6/6   N66  1150    2400000000
# 2106             9                           MgO   MGO  3600  205000000000
# 1381             6      Glass-filled epoxy (35%)   GFE  1900   25000000000
# 299              1                     Nylon 6/6   N66  1150    2400000000
# 1669             7  Glass-filled polyester (35%)   GFP  2000   15700000000
# 540              2                         Epoxy   EPY  1250    3350000000
# 1226             5           S-glass epoxy (45%)   SGE  1800   39500000000
# 1143             5           S-glass epoxy (45%)   SGE  1800   39500000000
#
#       cost_per_kilogram  q (Ordering materials)  Unnamed: 0_y  length  height  \
# 909                2.40                    1600            45    0.30   0.200
# 396                3.30                    1150           180    0.55   0.200
# 885                2.40                    1600            21    0.30   0.050
# 1255               3.76                    1800           175    0.55   0.125
# 1354               3.86                    1900            58    0.55   0.200
# 2591               1.94                    7150           215    0.55   0.550
# 1642               2.40                    2000           130    0.05   0.550
# 28                 0.85                     900            28    0.55   0.050
# 2532               1.94                    7150           156    0.30   0.200
# 1858              80.00                    2700           130    0.05   0.550
# 680                4.20                    1350            32    0.05   0.550
# 748                4.20                    1350           100    0.05   0.200
# 335                3.30                    1150           119    0.30   0.050
# 2106             134.00                    3600           162    0.55   0.125
# 1381               3.86                    1900            85    0.05   0.125
# 299                3.30                    1150            83    0.55   0.550
# 1669               2.40                    2000           157    0.30   0.200
# 540                2.76                    1250           108    0.30   0.050
# 1226               3.76                    1800           146    0.30   0.125
# 1143               3.76                    1800            63    0.05   0.050
#
#       width  angle of attack  length*heigth*width (Ordering Wings)  \
# 909    0.05            0.157                              0.003000
# 396    2.54            0.785                              0.279400
# 885    0.05            0.785                              0.000750
# 1255   3.00            0.785                              0.206250
# 1354   0.05            0.785                              0.005500
# 2591   3.00            0.785                              0.907500
# 1642   2.54            0.628                              0.069850
# 28     0.05            0.000                              0.001375
# 2532   2.54            0.314                              0.152400
# 1858   2.54            0.628                              0.069850
# 680    0.05            0.628                              0.001375
# 748    2.54            0.000                              0.025400
# 335    3.00            0.785                              0.045000
# 2106   2.54            0.785                              0.174625
# 1381   2.54            0.157                              0.015875
# 299    0.05            0.000                              0.015125
# 1669   2.54            0.785                              0.152400
# 540    2.54            0.000                              0.038100
# 1226   2.54            0.157                              0.095250
# 1143   2.54            0.314                              0.006350
#
#                               Suppliers
# 909              [Supplier6, Supplier3]
# 396              [Supplier3, Supplier4]
# 885   [Supplier4, Supplier1, Supplier7]
# 1255                        [Supplier6]
# 1354  [Supplier7, Supplier1, Supplier3]
# 2591  [Supplier3, Supplier1, Supplier5]
# 1642             [Supplier4, Supplier3]
# 28               [Supplier7, Supplier5]
# 2532  [Supplier5, Supplier3, Supplier1]
# 1858             [Supplier6, Supplier2]
# 680              [Supplier6, Supplier4]
# 748   [Supplier6, Supplier5, Supplier3]
# 335              [Supplier7, Supplier1]
# 2106                        [Supplier5]
# 1381  [Supplier5, Supplier3, Supplier2]
# 299              [Supplier3, Supplier5]
# 1669                        [Supplier1]
# 540              [Supplier2, Supplier3]
# 1226                        [Supplier7]
# 1143                        [Supplier7]
